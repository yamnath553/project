# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
gdp_data = pd.read_csv('C:/Users/dahal/Downloads/gdp_csv.csv')

# %%
gdp_data.head(10)
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10
# 5   Arab World          ARB  1973  5.501839e+10
# 6   Arab World          ARB  1974  1.051458e+11
# 7   Arab World          ARB  1975  1.163370e+11
# 8   Arab World          ARB  1976  1.448462e+11
# 9   Arab World          ARB  1977  1.673083e+11

# %%
print("Initial Dataset Info:")
print(gdp_data.info())
print("\nFirst Few Rows of Dataset:")
print(gdp_data.head())
# Out:
# Initial Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11507 entries, 0 to 11506
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  11507 non-null  object
#  1   Country Code  11507 non-null  object
#  2   Year          11507 non-null  int64
#  3   Value         11507 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 359.7+ KB
# None
#
# First Few Rows of Dataset:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
missing_values = gdp_data.isnull().sum()
print("\nMissing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# Country Name    0
# Country Code    0
# Year            0
# Value           0
# dtype: int64

# %%
gdp_data = gdp_data[gdp_data['Value'] > 0]

# %%
gdp_data
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
print("\nSummary Statistics:")
print(gdp_data.describe())
# Out:
# Summary Statistics:
#                Year         Value
# count  11507.000000  1.150700e+04
# mean    1991.265230  1.005972e+12
# std       15.886648  4.533056e+12
# min     1960.000000  8.824448e+06
# 25%     1978.000000  2.056874e+09
# 50%     1993.000000  1.436880e+10
# 75%     2005.000000  1.796394e+11
# max     2016.000000  7.904923e+13

# %%
plt.figure(figsize=(10, 6))
country_data = gdp_data[gdp_data['Country Name'] == 'India']
plt.plot(country_data['Year'], country_data['Value'], marker='o')
plt.title('GDP Trend for India')
plt.xlabel('Year')
plt.ylabel('GDP (in USD)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
country_data = gdp_data[gdp_data['Country Name'] == 'China']
plt.plot(country_data['Year'], country_data['Value'], marker='o')
plt.title('GDP Trend for China')
plt.xlabel('Year')
plt.ylabel('GDP (in USD)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
country_data = gdp_data[gdp_data['Country Name'] == 'Nepal']
plt.plot(country_data['Year'], country_data['Value'], marker='o')
plt.title('GDP Trend for Nepal')
plt.xlabel('Year')
plt.ylabel('GDP (in USD)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(gdp_data['Value'], bins=50, kde=True, color='blue')
plt.title('Distribution of GDP Values')
plt.xlabel('GDP Value')
plt.ylabel('Frequency')
plt.show()

# %%
fig = px.scatter(gdp_data, x='Year', y='Value', color='Country Name',
                 title='GDP Trends for All Countries',
                 labels={'Value': 'GDP Value', 'Year': 'Year'})
fig.show()

# %%
cleaned_file_path = 'C:/Users/dahal/Downloads/cleaned_gdp_data.csv'
gdp_data.to_csv(cleaned_file_path, index=False)
print(f"Cleaned data saved to {cleaned_file_path}")
# Out:
# Cleaned data saved to C:/Users/dahal/Downloads/cleaned_gdp_data.csv
